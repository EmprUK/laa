# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('wine1.csv')
df.head()
# Out:
#    A      B     C     D     E    F     G     H     I     J     K     L     M  \
# 0  1  14.23  1.71  2.43  15.6  127  2.80  3.06  0.28  2.29  5.64  1.04  3.92
# 1  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 2  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 3  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 4  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
#
#       N
# 0  1065
# 1  1050
# 2  1185
# 3  1480
# 4   735

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# %%
km=KMeans(n_clusters=3, max_iter=400,verbose=True,tol=0.2)

# %%
pred = km.fit_predict(df[['B','C']])
# Out:
# Initialization complete
# Iteration 0, inertia 114.47120000000001.
# Converged at iteration 0: center shift 0.1533284418007555 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 113.05080000000001.
# Iteration 1, inertia 97.96847536884468.
# Converged at iteration 1: center shift 0.03663623368172544 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 188.0781.
# Iteration 1, inertia 100.76811295633834.
# Converged at iteration 1: center shift 0.057413259306426094 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 186.72890000000007.
# Iteration 1, inertia 146.38448349966774.
# Converged at iteration 1: center shift 0.05036183460067529 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 201.2899.
# Iteration 1, inertia 113.31573242868629.
# Converged at iteration 1: center shift 0.14204633265383473 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 169.79540000000011.
# Iteration 1, inertia 98.61010759837751.
# Converged at iteration 1: center shift 0.03767295859301958 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 157.32960000000008.
# Iteration 1, inertia 97.63520111677192.
# Converged at iteration 1: center shift 0.032662118405007635 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 111.1257.
# Converged at iteration 0: center shift 0.13875562686504248 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 131.23320000000007.
# Iteration 1, inertia 96.26919270800303.
# Converged at iteration 1: center shift 0.005659193545842631 within tolerance 0.1896363811387452.
# Initialization complete
# Iteration 0, inertia 111.75500000000001.
# Converged at iteration 0: center shift 0.1388855916429083 within tolerance 0.1896363811387452.
# c:\Users\hp\anaconda3\envs\ML_Lab1\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.scatter(df['B'], df['C'],c=df['A'])

# %%
score = accuracy_score(df['A'], pred)
score
# Out:
# 0.06179775280898876

# %%
plt.scatter(df['B'], df['C'], c=pred)
plt.scatter(km.cluster_centers_[:,0] ,km.cluster_centers_[:,1], color='black')
